# %% [markdown]
# # Lab 7 Neural Language Model
# A language model predicts the next word in the sequence based on the specific words that have come before it in the sequence.
#
# It is also possible to develop language models at the character level using neural networks. The benefit of character-based language models is their small vocabulary and flexibility in handling any words, punctuation, and other document structure. This comes at the cost of requiring larger models that are slower to train.
#
# Nevertheless, in the field of neural language models, character-based models offer a lot of promise for a general, flexible and powerful approach to language modeling.

# %% [markdown]
# As a prerequisite for the lab, make sure to pip install:
# - keras
# - tensorflow
# - h5py

# %% [markdown]
# # Source Text Creation

# %% [markdown]
# To start out with, we'll be using a simple nursery rhyme. It's quite short so we can actually train something on your CPU and see relatively interesting results. Please copy and paste the following text in a text file and save it as "rhyme.txt". Place this in the same directory as this jupyter notebook:

# %%
# !pip install tensorflow
# !pip install keras
# !pip install h5py
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (2.3.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.18.5)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.33.2)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.4.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.12.4)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.9.2->tensorflow) (50.3.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.4.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (3.3.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.17.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (2.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.6)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (3.4.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.4.8)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (2.4.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras) (1.15.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
s='Sing a song of sixpence,\
A pocket full of rye.\
Four and twenty blackbirds,\
Baked in a pie.\
When the pie was opened\
The birds began to sing;\
Wasn’t that a dainty dish,\
To set before the king.\
The king was in his counting house,\
Counting out his money;\
The queen was in the parlour,\
Eating bread and honey.\
The maid was in the garden,\
Hanging out the clothes,\
When down came a blackbird\
And pecked off her nose.'

with open('rhymes.txt','w') as f:
  f.write(s)

# %% [markdown]
# # Sequence Generation
#
# A language model must be trained on the text, and in the case of a character-based language model, the input and output sequences must be characters.
#
# The number of characters used as input will also define the number of characters that will need to be provided to the model in order to elicit the first predicted character.
#
# After the first character has been generated, it can be appended to the input sequence and used as input for the model to generate the next character.
#
# Longer sequences offer more context for the model to learn what character to output next but take longer to train and impose more burden on seeding the model when generating text.
#
# We will use an arbitrary length of 10 characters for this model.
#
# There is not a lot of text, and 10 characters is a few words.
#
# We can now transform the raw text into a form that our model can learn; specifically, input and output sequences of characters.

# %%
#load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text
# save tokens to file, one dialog per line
def save_doc(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()

# %%
#load text
raw_text = load_doc('rhymes.txt')
print(raw_text)

# clean
tokens = raw_text.split()
raw_text = ' '.join(tokens)

# organize into sequences of characters
length = 10
sequences = list()
for i in range(length, len(raw_text)):
    # select sequence of tokens
    seq = raw_text[i-length:i+1]
    # store
    sequences.append(seq)
print('Total Sequences: %d' % len(sequences))
# Out:
# Sing a song of sixpence,A pocket full of rye.Four and twenty blackbirds,Baked in a pie.When the pie was openedThe birds began to sing;Wasn’t that a dainty dish,To set before the king.The king was in his counting house,Counting out his money;The queen was in the parlour,Eating bread and honey.The maid was in the garden,Hanging out the clothes,When down came a blackbirdAnd pecked off her nose.
# Total Sequences: 384

# %%
# save sequences to file
out_filename = 'char_sequences.txt'
save_doc(sequences, out_filename)

# %% [markdown]
# # Train a Model
# In this section, we will develop a neural language model for the prepared sequence data.
#
# The model will read encoded characters and predict the next character in the sequence. A Long Short-Term Memory recurrent neural network hidden layer will be used to learn the context from the input sequence in order to make the predictions.

# %%
from numpy import array
from pickle import dump
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# %%
# load

in_filename = 'char_sequences.txt'
raw_text = load_doc(in_filename)
lines = raw_text.split('\n')

# %% [markdown]
# The sequences of characters must be encoded as integers.This means that each unique character will be assigned a specific integer value and each sequence of characters will be encoded as a sequence of integers. We can create the mapping given a sorted set of unique characters in the raw input data. The mapping is a dictionary of character values to integer values.
#
# Next, we can process each sequence of characters one at a time and use the dictionary mapping to look up the integer value for each character. The result is a list of integer lists.
#
# We need to know the size of the vocabulary later. We can retrieve this as the size of the dictionary mapping.

# %%
# integer encode sequences of characters
chars = sorted(list(set(raw_text)))
mapping = dict((c, i) for i, c in enumerate(chars))
sequences = list()
for line in lines:
    # integer encode line
    encoded_seq = [mapping[char] for char in line]
    # store
    sequences.append(encoded_seq)

# vocabulary size
vocab_size = len(mapping)
print('Vocabulary Size: %d' % vocab_size)

# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
sequences = [to_categorical(x, num_classes=vocab_size) for x in X]
X = array(sequences)
y = to_categorical(y, num_classes=vocab_size)
# Out:
# Vocabulary Size: 38

# %% [markdown]
# The model is defined with an input layer that takes sequences that have 10 time steps and 38 features for the one hot encoded input sequences. Rather than specify these numbers, we use the second and third dimensions on the X input data. This is so that if we change the length of the sequences or size of the vocabulary, we do not need to change the model definition.
#
# The model has a single LSTM hidden layer with 75 memory cells. The model has a fully connected output layer that outputs one vector with a probability distribution across all characters in the vocabulary. A softmax activation function is used on the output layer to ensure the output has the properties of a probability distribution.
#
# The model is learning a multi-class classification problem, therefore we use the categorical log loss intended for this type of problem. The efficient Adam implementation of gradient descent is used to optimize the model and accuracy is reported at the end of each batch update. The model is fit for 50 training epochs.
#
# # To Do:
# - Try different numbers of memory cells
# - Try different types and amounts of recurrent and fully connected layers
# - Try different lengths of training epochs
# - Try different sequence lengths and pre-processing of data
# - Try regularization techniques such as Dropout

# %%
# define model
model = Sequential()
model.add(LSTM(75, input_shape=(X.shape[1], X.shape[2])))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit model
history=model.fit(X, y, epochs=50)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 75)                34200
# _________________________________________________________________
# dense (Dense)                (None, 38)                2888
# =================================================================
# Total params: 37,088
# Trainable params: 37,088
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 12/12 [==============================] - 0s 6ms/step - loss: 3.6113 - accuracy: 0.1042
# Epoch 2/50
# 12/12 [==============================] - 0s 5ms/step - loss: 3.5190 - accuracy: 0.1615
# Epoch 3/50
# 12/12 [==============================] - 0s 5ms/step - loss: 3.2327 - accuracy: 0.1589
# Epoch 4/50
# 12/12 [==============================] - 0s 6ms/step - loss: 3.1128 - accuracy: 0.1615
# Epoch 5/50
# 12/12 [==============================] - 0s 6ms/step - loss: 3.0642 - accuracy: 0.1745
# Epoch 6/50
# 12/12 [==============================] - 0s 5ms/step - loss: 3.0368 - accuracy: 0.1589
# Epoch 7/50
# 12/12 [==============================] - 0s 6ms/step - loss: 3.0261 - accuracy: 0.1589
# Epoch 8/50
# 12/12 [==============================] - 0s 6ms/step - loss: 3.0191 - accuracy: 0.1641
# Epoch 9/50
# 12/12 [==============================] - 0s 5ms/step - loss: 3.0030 - accuracy: 0.1615
# Epoch 10/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.9890 - accuracy: 0.1589
# Epoch 11/50
# 12/12 [==============================] - 0s 5ms/step - loss: 2.9636 - accuracy: 0.1589
# Epoch 12/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.9477 - accuracy: 0.1615
# Epoch 13/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.9281 - accuracy: 0.1615
# Epoch 14/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.9133 - accuracy: 0.1823
# Epoch 15/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.8848 - accuracy: 0.1771
# Epoch 16/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.8491 - accuracy: 0.2005
# Epoch 17/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.8271 - accuracy: 0.1849
# Epoch 18/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.7859 - accuracy: 0.2188
# Epoch 19/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.7619 - accuracy: 0.2188
# Epoch 20/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.7251 - accuracy: 0.2240
# Epoch 21/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.6788 - accuracy: 0.2422
# Epoch 22/50
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6459 - accuracy: 0.2734
# Epoch 23/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.6079 - accuracy: 0.2630
# Epoch 24/50
# 12/12 [==============================] - 0s 5ms/step - loss: 2.5685 - accuracy: 0.2917
# Epoch 25/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.5171 - accuracy: 0.2917
# Epoch 26/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.4809 - accuracy: 0.2969
# Epoch 27/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.4528 - accuracy: 0.2917
# Epoch 28/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.4046 - accuracy: 0.3021
# Epoch 29/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3455 - accuracy: 0.3203
# Epoch 30/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.3010 - accuracy: 0.3542
# Epoch 31/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.2525 - accuracy: 0.3594
# Epoch 32/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.2008 - accuracy: 0.3568
# Epoch 33/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.1618 - accuracy: 0.3854
# Epoch 34/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.1422 - accuracy: 0.3620
# Epoch 35/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.1289 - accuracy: 0.3776
# Epoch 36/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.0636 - accuracy: 0.3958
# Epoch 37/50
# 12/12 [==============================] - 0s 6ms/step - loss: 2.0051 - accuracy: 0.4297
# Epoch 38/50
# 12/12 [==============================] - 0s 6ms/step - loss: 1.9640 - accuracy: 0.4141
# Epoch 39/50
# 12/12 [==============================] - 0s 5ms/step - loss: 1.9183 - accuracy: 0.4505
# Epoch 40/50
# 12/12 [==============================] - 0s 6ms/step - loss: 1.8950 - accuracy: 0.4349
# Epoch 41/50
# 12/12 [==============================] - 0s 5ms/step - loss: 1.8218 - accuracy: 0.4870
# Epoch 42/50
# 12/12 [==============================] - 0s 6ms/step - loss: 1.7833 - accuracy: 0.4896
# Epoch 43/50
# 12/12 [==============================] - 0s 7ms/step - loss: 1.7562 - accuracy: 0.5130
# Epoch 44/50
# 12/12 [==============================] - 0s 6ms/step - loss: 1.7061 - accuracy: 0.5417
# Epoch 45/50
# 12/12 [==============================] - 0s 6ms/step - loss: 1.6700 - accuracy: 0.5495
# Epoch 46/50
# 12/12 [==============================] - 0s 5ms/step - loss: 1.6230 - accuracy: 0.5781
# Epoch 47/50
# 12/12 [==============================] - 0s 6ms/step - loss: 1.5816 - accuracy: 0.5651
# Epoch 48/50
# 12/12 [==============================] - 0s 6ms/step - loss: 1.5501 - accuracy: 0.5781
# Epoch 49/50
# 12/12 [==============================] - 0s 6ms/step - loss: 1.5011 - accuracy: 0.6094
# Epoch 50/50
# 12/12 [==============================] - 0s 8ms/step - loss: 1.4646 - accuracy: 0.6302

# %%
# save the model to file
model.save('model.h5')
# save the mapping
dump(mapping, open('mapping.pkl', 'wb'))

# %%
X.shape
# Out:
# (384, 10, 38)

# %% [markdown]
# # Generating Text

# %% [markdown]
# We must provide sequences of 10 characters as input to the model in order to start the generation process. We will pick these manually. A given input sequence will need to be prepared in the same way as preparing the training data for the model.

# %%
from pickle import load
from keras.models import load_model
from keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
import numpy as np

# generate a sequence of characters with a language model
def generate_seq(model, mapping, seq_length, seed_text, n_chars):
    in_text = seed_text
    # generate a fixed number of characters
    for _ in range(n_chars):
        # encode the characters as integers
        encoded = [mapping[char] for char in in_text]
        # truncate sequences to a fixed length
        encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
        # one hot encode
        encoded = to_categorical(encoded, num_classes=len(mapping))
        # predict character
        # yhat = model.predict_classes(encoded, verbose=0)
        yhat = np.argmax(model.predict(encoded), axis=-1)
        # reverse map integer to character
        out_char = ''
        for char, index in mapping.items():
            if index == yhat:
                out_char = char
                break
        # append to input
        in_text += char
    return in_text

# load the model
model = load_model('model.h5')
# load the mapping
mapping = load(open('mapping.pkl', 'rb'))

# %% [markdown]
# Running the example generates three sequences of text.
#
# The first is a test to see how the model does at starting from the beginning of the rhyme. The second is a test to see how well it does at beginning in the middle of a line. The final example is a test to see how well it does with a sequence of characters never seen before.

# %%
# test start of rhyme
print(generate_seq(model, mapping, 10, 'Sing a son', 20))
# test mid-line
print(generate_seq(model, mapping, 10, 'king was i', 20))
# test not in original
print(generate_seq(model, mapping, 10, 'hello worl', 20))
# Out:
# Sing a song onf out of e fe of
# king was in hee hoe ee  oue  o
# hello worl.,Fe a ngin oous hhe

# %% [markdown]
#     Sing a song of sixpence,
#     A pocket full of rye.
#     Four and twenty blackbirds,
#     Baked in a pie.
#
#     When the pie was opened
#     The birds began to sing;
#     Wasn’t that a dainty dish,
#     To set before the king.
#
#     The king was in his counting house,
#     Counting out his money;
#     The queen was in the parlour,
#     Eating bread and honey.
#
#     The maid was in the garden,
#     Hanging out the clothes,
#     When down came a blackbird
#     And pecked off her nose.

# %% [markdown]
# If the results aren't satisfactory, try out the suggestions above or these below:
# - Padding. Update the example to provides sequences line by line only and use padding to fill out each sequence to the maximum line length.
# - Sequence Length. Experiment with different sequence lengths and see how they impact the behavior of the model.
# - Tune Model. Experiment with different model configurations, such as the number of memory cells and epochs, and try to develop a better model for fewer resources.

# %% [markdown]
# # Deliverables to receive credit
#
# 1. (4 points) Optimize the cells above to tune the model so that it generates text that closely resembles the orginal line from the rhyme, or at least generates sensible words. It's okay if the third example using unseen text still looks somewhat strange  though. Again, this is a toy problem, as language models require a lot of computation. This toy problem is great for rapid experimentation to explore different aspects of deep learning language models.
# 2. (3 points) Write a function to split the text corpus file into training and validation and pipe the validation data into the model.fit() function to be able to track validation error per epoch. Lookup Keras documentation to see how this is handled.
# 3. (3 points) Write a summary (methods and results) in the cells below of the different things you applied. You must include your intuitions behind what did work and what did not work well.
# 4. (Extra Credit 2.5 points) Do something even more interesting. Try a different source text. Train a word-level model. We'll leave it up to your creativity to explore and write a summary of your methods and results.

# %%
# 1.1 Define model 1 with 100 memory cells in the single LSTM hidden layer, and 100 training epoches
model1 = Sequential()
model1.add(LSTM(100, input_shape=(X.shape[1], X.shape[2])))
model1.add(Dense(vocab_size, activation='softmax'))
print(model1.summary())
# compile model
model1.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit model
history=model1.fit(X, y, epochs=100)
# Out:
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_40 (LSTM)               (None, 100)               55600
# _________________________________________________________________
# dense_31 (Dense)             (None, 38)                3838
# =================================================================
# Total params: 59,438
# Trainable params: 59,438
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.6055 - accuracy: 0.0990
# Epoch 2/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4548 - accuracy: 0.1432
# Epoch 3/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.1565 - accuracy: 0.1302
# Epoch 4/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.0752 - accuracy: 0.1589
# Epoch 5/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.0515 - accuracy: 0.1589
# Epoch 6/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.0270 - accuracy: 0.1849
# Epoch 7/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.0045 - accuracy: 0.1641
# Epoch 8/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.9808 - accuracy: 0.1589
# Epoch 9/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.9540 - accuracy: 0.1693
# Epoch 10/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.9253 - accuracy: 0.1797
# Epoch 11/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.9030 - accuracy: 0.1719
# Epoch 12/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.8547 - accuracy: 0.1979
# Epoch 13/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.8136 - accuracy: 0.1875
# Epoch 14/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.7876 - accuracy: 0.1979
# Epoch 15/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.7628 - accuracy: 0.1953
# Epoch 16/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.7557 - accuracy: 0.2396
# Epoch 17/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6797 - accuracy: 0.2292
# Epoch 18/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6369 - accuracy: 0.2526
# Epoch 19/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.5988 - accuracy: 0.2500
# Epoch 20/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.5597 - accuracy: 0.2474
# Epoch 21/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.5319 - accuracy: 0.2786
# Epoch 22/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.5065 - accuracy: 0.2474
# Epoch 23/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4504 - accuracy: 0.2995
# Epoch 24/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.4286 - accuracy: 0.2812
# Epoch 25/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3888 - accuracy: 0.3177
# Epoch 26/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3267 - accuracy: 0.3099
# Epoch 27/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.2760 - accuracy: 0.3672
# Epoch 28/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.2269 - accuracy: 0.3828
# Epoch 29/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.1758 - accuracy: 0.3802
# Epoch 30/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.1290 - accuracy: 0.3906
# Epoch 31/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.0960 - accuracy: 0.4167
# Epoch 32/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.0494 - accuracy: 0.4167
# Epoch 33/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.9717 - accuracy: 0.4609
# Epoch 34/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.9159 - accuracy: 0.4635
# Epoch 35/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.8686 - accuracy: 0.4531
# Epoch 36/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.8272 - accuracy: 0.4714
# Epoch 37/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7736 - accuracy: 0.5104
# Epoch 38/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7074 - accuracy: 0.5443
# Epoch 39/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6677 - accuracy: 0.5547
# Epoch 40/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.5914 - accuracy: 0.5521
# Epoch 41/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.5355 - accuracy: 0.6016
# Epoch 42/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.4932 - accuracy: 0.6094
# Epoch 43/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.4786 - accuracy: 0.6094
# Epoch 44/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3984 - accuracy: 0.6380
# Epoch 45/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3564 - accuracy: 0.6562
# Epoch 46/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2969 - accuracy: 0.6797
# Epoch 47/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2465 - accuracy: 0.7135
# Epoch 48/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.1769 - accuracy: 0.7214
# Epoch 49/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1313 - accuracy: 0.7448
# Epoch 50/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1407 - accuracy: 0.7526
# Epoch 51/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1094 - accuracy: 0.7318
# Epoch 52/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.0494 - accuracy: 0.7656
# Epoch 53/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9837 - accuracy: 0.8229
# Epoch 54/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9586 - accuracy: 0.7943
# Epoch 55/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8982 - accuracy: 0.8255
# Epoch 56/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.8514 - accuracy: 0.8464
# Epoch 57/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.8054 - accuracy: 0.8646
# Epoch 58/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7676 - accuracy: 0.8776
# Epoch 59/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7319 - accuracy: 0.8880
# Epoch 60/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6949 - accuracy: 0.8958
# Epoch 61/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6618 - accuracy: 0.9062
# Epoch 62/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6324 - accuracy: 0.9115
# Epoch 63/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6134 - accuracy: 0.9219
# Epoch 64/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5827 - accuracy: 0.9349
# Epoch 65/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5690 - accuracy: 0.9323
# Epoch 66/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5194 - accuracy: 0.9401
# Epoch 67/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5150 - accuracy: 0.9479
# Epoch 68/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4985 - accuracy: 0.9557
# Epoch 69/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4827 - accuracy: 0.9635
# Epoch 70/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4548 - accuracy: 0.9635
# Epoch 71/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4139 - accuracy: 0.9557
# Epoch 72/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3958 - accuracy: 0.9792
# Epoch 73/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3607 - accuracy: 0.9766
# Epoch 74/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.3457 - accuracy: 0.9818
# Epoch 75/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3360 - accuracy: 0.9792
# Epoch 76/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3176 - accuracy: 0.9766
# Epoch 77/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3052 - accuracy: 0.9792
# Epoch 78/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2904 - accuracy: 0.9792
# Epoch 79/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2750 - accuracy: 0.9870
# Epoch 80/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2608 - accuracy: 0.9844
# Epoch 81/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2443 - accuracy: 0.9896
# Epoch 82/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2331 - accuracy: 0.9896
# Epoch 83/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2214 - accuracy: 0.9896
# Epoch 84/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2173 - accuracy: 0.9870
# Epoch 85/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2095 - accuracy: 0.9922
# Epoch 86/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2019 - accuracy: 0.9922
# Epoch 87/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1915 - accuracy: 0.9948
# Epoch 88/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1843 - accuracy: 0.9896
# Epoch 89/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1776 - accuracy: 0.9870
# Epoch 90/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1673 - accuracy: 0.9870
# Epoch 91/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1631 - accuracy: 0.9922
# Epoch 92/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1537 - accuracy: 0.9948
# Epoch 93/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1523 - accuracy: 0.9948
# Epoch 94/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1467 - accuracy: 0.9896
# Epoch 95/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1549 - accuracy: 0.9818
# Epoch 96/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1486 - accuracy: 0.9896
# Epoch 97/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1383 - accuracy: 0.9870
# Epoch 98/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1358 - accuracy: 0.9922
# Epoch 99/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1289 - accuracy: 0.9922
# Epoch 100/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1225 - accuracy: 0.9922

# %%
# save the model to file
model1.save('model1.h5')

# %%
# test start of rhyme
print(generate_seq(model1, mapping, 10, 'Sing a son', 20))
# test mid-line
print(generate_seq(model1, mapping, 10, 'king was i', 20))
# test not in original
print(generate_seq(model1, mapping, 10, 'hello worl', 20))
# Out:
# Sing a song of sixpence,A pock
# king was in his counting house
# hello worl,,oueddgtf  en tt lf

# %% [markdown]
# **The first model has very high accuracy. The prediction on the first and second test examples look great. The third example doesn't look good, but it's ok**

# %%
# 1.2 Define model 2, adding on model 1 with one dropout layer between input and output layers.
from keras.layers import Dropout

model2 = Sequential()
model2.add(LSTM(100, input_shape=(X.shape[1], X.shape[2])))
model2.add(Dropout(rate=0.2))
model2.add(Dense(vocab_size, activation='softmax'))
print(model2.summary())
# compile model
model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit model
history=model2.fit(X, y, epochs=100)
# Out:
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_41 (LSTM)               (None, 100)               55600
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 38)                3838
# =================================================================
# Total params: 59,438
# Trainable params: 59,438
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.6103 - accuracy: 0.0885
# Epoch 2/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4939 - accuracy: 0.1615
# Epoch 3/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.2364 - accuracy: 0.1589
# Epoch 4/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.1021 - accuracy: 0.1641
# Epoch 5/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.0572 - accuracy: 0.1562
# Epoch 6/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.0397 - accuracy: 0.1562
# Epoch 7/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.0384 - accuracy: 0.1615
# Epoch 8/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.9894 - accuracy: 0.1719
# Epoch 9/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.9937 - accuracy: 0.1667
# Epoch 10/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.9599 - accuracy: 0.1667
# Epoch 11/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.9362 - accuracy: 0.1667
# Epoch 12/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.8930 - accuracy: 0.2031
# Epoch 13/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.8534 - accuracy: 0.2005
# Epoch 14/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.8383 - accuracy: 0.2083
# Epoch 15/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.8120 - accuracy: 0.2109
# Epoch 16/100
# 12/12 [==============================] - 0s 9ms/step - loss: 2.7892 - accuracy: 0.2188
# Epoch 17/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.7363 - accuracy: 0.2214
# Epoch 18/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.7035 - accuracy: 0.2448
# Epoch 19/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6592 - accuracy: 0.2344
# Epoch 20/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6124 - accuracy: 0.2448
# Epoch 21/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.5704 - accuracy: 0.2474
# Epoch 22/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.5626 - accuracy: 0.2448
# Epoch 23/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.5062 - accuracy: 0.2656
# Epoch 24/100
# 12/12 [==============================] - 0s 9ms/step - loss: 2.4771 - accuracy: 0.2786
# Epoch 25/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4307 - accuracy: 0.2604
# Epoch 26/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.4117 - accuracy: 0.2839
# Epoch 27/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.3561 - accuracy: 0.2943
# Epoch 28/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3065 - accuracy: 0.3177
# Epoch 29/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.2467 - accuracy: 0.3646
# Epoch 30/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.2132 - accuracy: 0.3542
# Epoch 31/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.1464 - accuracy: 0.3542
# Epoch 32/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.0566 - accuracy: 0.3750
# Epoch 33/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.1051 - accuracy: 0.3750
# Epoch 34/100
# 12/12 [==============================] - 0s 9ms/step - loss: 2.0649 - accuracy: 0.3776
# Epoch 35/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.0430 - accuracy: 0.4010
# Epoch 36/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.9192 - accuracy: 0.4505
# Epoch 37/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.8923 - accuracy: 0.4557
# Epoch 38/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.7906 - accuracy: 0.4922
# Epoch 39/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7893 - accuracy: 0.4635
# Epoch 40/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.7284 - accuracy: 0.4844
# Epoch 41/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.6869 - accuracy: 0.5391
# Epoch 42/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.6460 - accuracy: 0.5312
# Epoch 43/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6092 - accuracy: 0.5260
# Epoch 44/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.5348 - accuracy: 0.5443
# Epoch 45/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.4973 - accuracy: 0.5521
# Epoch 46/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.4667 - accuracy: 0.5990
# Epoch 47/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.4146 - accuracy: 0.6172
# Epoch 48/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.3629 - accuracy: 0.6016
# Epoch 49/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3756 - accuracy: 0.6120
# Epoch 50/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.3054 - accuracy: 0.6536
# Epoch 51/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2488 - accuracy: 0.6562
# Epoch 52/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.1773 - accuracy: 0.6875
# Epoch 53/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1613 - accuracy: 0.7135
# Epoch 54/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.1224 - accuracy: 0.7005
# Epoch 55/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.0726 - accuracy: 0.7109
# Epoch 56/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.0457 - accuracy: 0.7422
# Epoch 57/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.0028 - accuracy: 0.7578
# Epoch 58/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9570 - accuracy: 0.7578
# Epoch 59/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9373 - accuracy: 0.7656
# Epoch 60/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.8832 - accuracy: 0.8047
# Epoch 61/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8835 - accuracy: 0.7943
# Epoch 62/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.8136 - accuracy: 0.7995
# Epoch 63/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8280 - accuracy: 0.8333
# Epoch 64/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7519 - accuracy: 0.8568
# Epoch 65/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7245 - accuracy: 0.8411
# Epoch 66/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7044 - accuracy: 0.8464
# Epoch 67/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6419 - accuracy: 0.8906
# Epoch 68/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6066 - accuracy: 0.8880
# Epoch 69/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5742 - accuracy: 0.9036
# Epoch 70/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5870 - accuracy: 0.8880
# Epoch 71/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5812 - accuracy: 0.8854
# Epoch 72/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5514 - accuracy: 0.9062
# Epoch 73/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5053 - accuracy: 0.9141
# Epoch 74/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4978 - accuracy: 0.9245
# Epoch 75/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4283 - accuracy: 0.9453
# Epoch 76/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4385 - accuracy: 0.9323
# Epoch 77/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4156 - accuracy: 0.9401
# Epoch 78/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4042 - accuracy: 0.9271
# Epoch 79/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3876 - accuracy: 0.9427
# Epoch 80/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3718 - accuracy: 0.9479
# Epoch 81/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3705 - accuracy: 0.9375
# Epoch 82/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3408 - accuracy: 0.9635
# Epoch 83/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3078 - accuracy: 0.9688
# Epoch 84/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3144 - accuracy: 0.9635
# Epoch 85/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2953 - accuracy: 0.9792
# Epoch 86/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2876 - accuracy: 0.9635
# Epoch 87/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2668 - accuracy: 0.9766
# Epoch 88/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2509 - accuracy: 0.9844
# Epoch 89/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2378 - accuracy: 0.9766
# Epoch 90/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2492 - accuracy: 0.9740
# Epoch 91/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2414 - accuracy: 0.9661
# Epoch 92/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2283 - accuracy: 0.9818
# Epoch 93/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2146 - accuracy: 0.9792
# Epoch 94/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2161 - accuracy: 0.9740
# Epoch 95/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2023 - accuracy: 0.9792
# Epoch 96/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1900 - accuracy: 0.9818
# Epoch 97/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1902 - accuracy: 0.9844
# Epoch 98/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2049 - accuracy: 0.9740
# Epoch 99/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1853 - accuracy: 0.9740
# Epoch 100/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1969 - accuracy: 0.9792

# %%
# save the model to file
model2.save('model2.h5')

# %%
# test start of rhyme
print(generate_seq(model2, mapping, 10, 'Sing a son', 20))
# test mid-line
print(generate_seq(model2, mapping, 10, 'king was i', 20))
# test not in original
print(generate_seq(model2, mapping, 10, 'hello worl', 20))
# Out:
# Sing a song of sixpence,A pock
# king was in his counting house
# hello worl,.Fo  krt. oulllltho

# %% [markdown]
# **The second model is also performing pretty well for the first two test cases. The third case is still not good, but it's ok. I added the dropout layer trying to regulate overfitting by dropping out some data during training.**

# %%
# 1.3 Define model 3, adding two hidden layers of fully-connected Dense layers
model3 = Sequential()
model3.add(LSTM(100, input_shape=(X.shape[1], X.shape[2])))
model3.add(Dropout(rate=0.2))
model3.add(Dense(50))
model3.add(Dense(50))
model3.add(Dense(vocab_size, activation='softmax'))
print(model3.summary())
# compile model
model3.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit model
history=model3.fit(X, y, epochs=100)
# Out:
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_44 (LSTM)               (None, 100)               55600
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_39 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_40 (Dense)             (None, 38)                1938
# =================================================================
# Total params: 65,138
# Trainable params: 65,138
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.5793 - accuracy: 0.1068
# Epoch 2/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.2987 - accuracy: 0.1406
# Epoch 3/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.1566 - accuracy: 0.1589
# Epoch 4/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.0882 - accuracy: 0.1641
# Epoch 5/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.0538 - accuracy: 0.1589
# Epoch 6/100
# 12/12 [==============================] - 0s 7ms/step - loss: 3.0293 - accuracy: 0.1641
# Epoch 7/100
# 12/12 [==============================] - 0s 8ms/step - loss: 3.0060 - accuracy: 0.1641
# Epoch 8/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.9756 - accuracy: 0.1719
# Epoch 9/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.9526 - accuracy: 0.1615
# Epoch 10/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.9041 - accuracy: 0.1797
# Epoch 11/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.8542 - accuracy: 0.2135
# Epoch 12/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.8440 - accuracy: 0.1979
# Epoch 13/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.7648 - accuracy: 0.2396
# Epoch 14/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.6842 - accuracy: 0.2656
# Epoch 15/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6773 - accuracy: 0.2500
# Epoch 16/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.5577 - accuracy: 0.2682
# Epoch 17/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.4511 - accuracy: 0.3021
# Epoch 18/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.4013 - accuracy: 0.3047
# Epoch 19/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.3037 - accuracy: 0.3333
# Epoch 20/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.2484 - accuracy: 0.3516
# Epoch 21/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.2548 - accuracy: 0.3464
# Epoch 22/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.2166 - accuracy: 0.3438
# Epoch 23/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.0936 - accuracy: 0.3906
# Epoch 24/100
# 12/12 [==============================] - 0s 7ms/step - loss: 2.0889 - accuracy: 0.3906
# Epoch 25/100
# 12/12 [==============================] - 0s 8ms/step - loss: 2.0130 - accuracy: 0.4141
# Epoch 26/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.9349 - accuracy: 0.4401
# Epoch 27/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.8634 - accuracy: 0.4531
# Epoch 28/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.8287 - accuracy: 0.4427
# Epoch 29/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.7898 - accuracy: 0.4453
# Epoch 30/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7400 - accuracy: 0.4557
# Epoch 31/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6703 - accuracy: 0.4896
# Epoch 32/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.6251 - accuracy: 0.5104
# Epoch 33/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.5833 - accuracy: 0.5000
# Epoch 34/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.5156 - accuracy: 0.5286
# Epoch 35/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.5218 - accuracy: 0.5469
# Epoch 36/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.4919 - accuracy: 0.5104
# Epoch 37/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3749 - accuracy: 0.5703
# Epoch 38/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3394 - accuracy: 0.5755
# Epoch 39/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2946 - accuracy: 0.5938
# Epoch 40/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2595 - accuracy: 0.6094
# Epoch 41/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2523 - accuracy: 0.5885
# Epoch 42/100
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2387 - accuracy: 0.5833
# Epoch 43/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1496 - accuracy: 0.6536
# Epoch 44/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.1145 - accuracy: 0.6432
# Epoch 45/100
# 12/12 [==============================] - 0s 9ms/step - loss: 1.0973 - accuracy: 0.6562
# Epoch 46/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0366 - accuracy: 0.6589
# Epoch 47/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0348 - accuracy: 0.6667
# Epoch 48/100
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0022 - accuracy: 0.6719
# Epoch 49/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.9309 - accuracy: 0.7188
# Epoch 50/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8888 - accuracy: 0.7240
# Epoch 51/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.9126 - accuracy: 0.6875
# Epoch 52/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.8691 - accuracy: 0.7240
# Epoch 53/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7987 - accuracy: 0.7500
# Epoch 54/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7826 - accuracy: 0.7578
# Epoch 55/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7725 - accuracy: 0.7604
# Epoch 56/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.7684 - accuracy: 0.7448
# Epoch 57/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6764 - accuracy: 0.7943
# Epoch 58/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6939 - accuracy: 0.7917
# Epoch 59/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6393 - accuracy: 0.8255
# Epoch 60/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6443 - accuracy: 0.7812
# Epoch 61/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5500 - accuracy: 0.8359
# Epoch 62/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5134 - accuracy: 0.8281
# Epoch 63/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5611 - accuracy: 0.8125
# Epoch 64/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5345 - accuracy: 0.8307
# Epoch 65/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5546 - accuracy: 0.8255
# Epoch 66/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5521 - accuracy: 0.8073
# Epoch 67/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4909 - accuracy: 0.8516
# Epoch 68/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4511 - accuracy: 0.8542
# Epoch 69/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4403 - accuracy: 0.8672
# Epoch 70/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4135 - accuracy: 0.8828
# Epoch 71/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3854 - accuracy: 0.8802
# Epoch 72/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3598 - accuracy: 0.8984
# Epoch 73/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3309 - accuracy: 0.9062
# Epoch 74/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3239 - accuracy: 0.8984
# Epoch 75/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3022 - accuracy: 0.9062
# Epoch 76/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3326 - accuracy: 0.8958
# Epoch 77/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2678 - accuracy: 0.9375
# Epoch 78/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2757 - accuracy: 0.9245
# Epoch 79/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2958 - accuracy: 0.9245
# Epoch 80/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2487 - accuracy: 0.9505
# Epoch 81/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2592 - accuracy: 0.9193
# Epoch 82/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2614 - accuracy: 0.9245
# Epoch 83/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2478 - accuracy: 0.9323
# Epoch 84/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2148 - accuracy: 0.9349
# Epoch 85/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2231 - accuracy: 0.9505
# Epoch 86/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2001 - accuracy: 0.9427
# Epoch 87/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2405 - accuracy: 0.9271
# Epoch 88/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2106 - accuracy: 0.9557
# Epoch 89/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1763 - accuracy: 0.9609
# Epoch 90/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1780 - accuracy: 0.9557
# Epoch 91/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1735 - accuracy: 0.9557
# Epoch 92/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1980 - accuracy: 0.9427
# Epoch 93/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1594 - accuracy: 0.9635
# Epoch 94/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1539 - accuracy: 0.9505
# Epoch 95/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1532 - accuracy: 0.9609
# Epoch 96/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1768 - accuracy: 0.9401
# Epoch 97/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1498 - accuracy: 0.9557
# Epoch 98/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1426 - accuracy: 0.9688
# Epoch 99/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1409 - accuracy: 0.9557
# Epoch 100/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1304 - accuracy: 0.9661

# %%
# save the model to file
model3.save('model3.h5')

# %%
# test start of rhyme
print(generate_seq(model3, mapping, 10, 'Sing a son', 20))
# test mid-line
print(generate_seq(model3, mapping, 10, 'king was i', 20))
# test not in original
print(generate_seq(model3, mapping, 10, 'hello worl', 20))
# Out:
# Sing a song of sixpence,A pock
# king was in his counting house
# hello worle.Fulr tindgd.To tth

# %% [markdown]
# **The model3 also performs well on the first two cases, still not well on the third case. However, the prediction on the third case looks a little more like real words. The overfit may has improved a little bit.**

# %%
# 2. Split the text corpus file into training and validation 

from sklearn.model_selection import train_test_split

# split the data into 80% train 20% validation
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
# Define a new model based on model3, called model_new
# pipe in validation sets to evaluate accuracy
model_new = Sequential()
model_new.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))
model_new.add(Dropout(rate=0.2))
model_new.add(Dense(50))
model_new.add(Dense(50))
model_new.add(Dense(vocab_size, activation='softmax'))
print(model_new.summary())
# compile model
model_new.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit model
history=model_new.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid))
# Out:
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_45 (LSTM)               (None, 100)               55600
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_42 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_43 (Dense)             (None, 38)                1938
# =================================================================
# Total params: 65,138
# Trainable params: 65,138
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 10/10 [==============================] - 1s 53ms/step - loss: 3.6167 - accuracy: 0.0879 - val_loss: 3.5666 - val_accuracy: 0.1558
# Epoch 2/100
# 10/10 [==============================] - 0s 10ms/step - loss: 3.4951 - accuracy: 0.1596 - val_loss: 3.3858 - val_accuracy: 0.1818
# Epoch 3/100
# 10/10 [==============================] - 0s 11ms/step - loss: 3.1979 - accuracy: 0.1531 - val_loss: 3.3224 - val_accuracy: 0.1818
# Epoch 4/100
# 10/10 [==============================] - 0s 11ms/step - loss: 3.0688 - accuracy: 0.1564 - val_loss: 3.2776 - val_accuracy: 0.1818
# Epoch 5/100
# 10/10 [==============================] - 0s 11ms/step - loss: 3.0474 - accuracy: 0.1694 - val_loss: 3.2900 - val_accuracy: 0.1818
# Epoch 6/100
# 10/10 [==============================] - 0s 12ms/step - loss: 3.0053 - accuracy: 0.1531 - val_loss: 3.2468 - val_accuracy: 0.1818
# Epoch 7/100
# 10/10 [==============================] - 0s 10ms/step - loss: 2.9776 - accuracy: 0.1629 - val_loss: 3.2357 - val_accuracy: 0.1688
# Epoch 8/100
# 10/10 [==============================] - 0s 10ms/step - loss: 2.9518 - accuracy: 0.1694 - val_loss: 3.2139 - val_accuracy: 0.1818
# Epoch 9/100
# 10/10 [==============================] - 0s 10ms/step - loss: 2.9129 - accuracy: 0.1629 - val_loss: 3.2432 - val_accuracy: 0.1818
# Epoch 10/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.8833 - accuracy: 0.1987 - val_loss: 3.2593 - val_accuracy: 0.1688
# Epoch 11/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.8392 - accuracy: 0.2248 - val_loss: 3.2001 - val_accuracy: 0.1558
# Epoch 12/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.8066 - accuracy: 0.1889 - val_loss: 3.2382 - val_accuracy: 0.1299
# Epoch 13/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.7407 - accuracy: 0.2443 - val_loss: 3.2479 - val_accuracy: 0.1558
# Epoch 14/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.6972 - accuracy: 0.2117 - val_loss: 3.2037 - val_accuracy: 0.1818
# Epoch 15/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.6527 - accuracy: 0.2573 - val_loss: 3.2317 - val_accuracy: 0.1558
# Epoch 16/100
# 10/10 [==============================] - 0s 12ms/step - loss: 2.5617 - accuracy: 0.2378 - val_loss: 3.1727 - val_accuracy: 0.1688
# Epoch 17/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.5338 - accuracy: 0.2476 - val_loss: 3.2104 - val_accuracy: 0.0909
# Epoch 18/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.5226 - accuracy: 0.2932 - val_loss: 3.2228 - val_accuracy: 0.1429
# Epoch 19/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.3914 - accuracy: 0.3029 - val_loss: 3.1882 - val_accuracy: 0.1688
# Epoch 20/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.3556 - accuracy: 0.3257 - val_loss: 3.1565 - val_accuracy: 0.1558
# Epoch 21/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.2611 - accuracy: 0.3485 - val_loss: 3.2626 - val_accuracy: 0.1429
# Epoch 22/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.1682 - accuracy: 0.3518 - val_loss: 3.2164 - val_accuracy: 0.1558
# Epoch 23/100
# 10/10 [==============================] - 0s 10ms/step - loss: 2.1270 - accuracy: 0.3550 - val_loss: 3.1881 - val_accuracy: 0.1948
# Epoch 24/100
# 10/10 [==============================] - 0s 10ms/step - loss: 2.0646 - accuracy: 0.3909 - val_loss: 3.2500 - val_accuracy: 0.1818
# Epoch 25/100
# 10/10 [==============================] - 0s 10ms/step - loss: 2.0037 - accuracy: 0.4235 - val_loss: 3.1749 - val_accuracy: 0.1429
# Epoch 26/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.9261 - accuracy: 0.3941 - val_loss: 3.2707 - val_accuracy: 0.1818
# Epoch 27/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.8570 - accuracy: 0.4463 - val_loss: 3.2962 - val_accuracy: 0.1688
# Epoch 28/100
# 10/10 [==============================] - 0s 12ms/step - loss: 1.8206 - accuracy: 0.4593 - val_loss: 3.3757 - val_accuracy: 0.1299
# Epoch 29/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.7252 - accuracy: 0.4495 - val_loss: 3.4345 - val_accuracy: 0.1818
# Epoch 30/100
# 10/10 [==============================] - 0s 13ms/step - loss: 1.6533 - accuracy: 0.4528 - val_loss: 3.3425 - val_accuracy: 0.1818
# Epoch 31/100
# 10/10 [==============================] - 0s 12ms/step - loss: 1.6787 - accuracy: 0.4528 - val_loss: 3.3017 - val_accuracy: 0.1688
# Epoch 32/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.5623 - accuracy: 0.5049 - val_loss: 3.5598 - val_accuracy: 0.1948
# Epoch 33/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.5025 - accuracy: 0.5472 - val_loss: 3.4677 - val_accuracy: 0.1948
# Epoch 34/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.4588 - accuracy: 0.5309 - val_loss: 3.4709 - val_accuracy: 0.1818
# Epoch 35/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.4210 - accuracy: 0.5668 - val_loss: 3.7516 - val_accuracy: 0.2338
# Epoch 36/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.3669 - accuracy: 0.5765 - val_loss: 3.5791 - val_accuracy: 0.1948
# Epoch 37/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.2977 - accuracy: 0.5765 - val_loss: 3.7558 - val_accuracy: 0.1558
# Epoch 38/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.2703 - accuracy: 0.5961 - val_loss: 3.8522 - val_accuracy: 0.1818
# Epoch 39/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.2720 - accuracy: 0.5961 - val_loss: 3.8569 - val_accuracy: 0.1948
# Epoch 40/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.1746 - accuracy: 0.6254 - val_loss: 3.9493 - val_accuracy: 0.2078
# Epoch 41/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.1784 - accuracy: 0.6221 - val_loss: 3.9835 - val_accuracy: 0.2338
# Epoch 42/100
# 10/10 [==============================] - 0s 12ms/step - loss: 1.0750 - accuracy: 0.6287 - val_loss: 3.8901 - val_accuracy: 0.1818
# Epoch 43/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.9966 - accuracy: 0.6710 - val_loss: 4.1134 - val_accuracy: 0.1948
# Epoch 44/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.0893 - accuracy: 0.6352 - val_loss: 3.9578 - val_accuracy: 0.2078
# Epoch 45/100
# 10/10 [==============================] - 0s 12ms/step - loss: 1.0474 - accuracy: 0.6873 - val_loss: 4.1818 - val_accuracy: 0.2208
# Epoch 46/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.0022 - accuracy: 0.6743 - val_loss: 4.0186 - val_accuracy: 0.1948
# Epoch 47/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.9097 - accuracy: 0.7394 - val_loss: 4.2164 - val_accuracy: 0.2078
# Epoch 48/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.9086 - accuracy: 0.7329 - val_loss: 4.1866 - val_accuracy: 0.2208
# Epoch 49/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.8408 - accuracy: 0.7036 - val_loss: 4.3516 - val_accuracy: 0.1948
# Epoch 50/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.8058 - accuracy: 0.7427 - val_loss: 4.5772 - val_accuracy: 0.2078
# Epoch 51/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.7635 - accuracy: 0.7915 - val_loss: 4.6408 - val_accuracy: 0.1558
# Epoch 52/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.7458 - accuracy: 0.7590 - val_loss: 4.9251 - val_accuracy: 0.1558
# Epoch 53/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.6797 - accuracy: 0.7850 - val_loss: 4.9434 - val_accuracy: 0.1948
# Epoch 54/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6891 - accuracy: 0.7883 - val_loss: 5.2606 - val_accuracy: 0.1429
# Epoch 55/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.7070 - accuracy: 0.7752 - val_loss: 4.9207 - val_accuracy: 0.2078
# Epoch 56/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5855 - accuracy: 0.8241 - val_loss: 5.2064 - val_accuracy: 0.1429
# Epoch 57/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5677 - accuracy: 0.8339 - val_loss: 5.1779 - val_accuracy: 0.1558
# Epoch 58/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5566 - accuracy: 0.8241 - val_loss: 5.4084 - val_accuracy: 0.1558
# Epoch 59/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5815 - accuracy: 0.8208 - val_loss: 5.3286 - val_accuracy: 0.2078
# Epoch 60/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4901 - accuracy: 0.8664 - val_loss: 5.5728 - val_accuracy: 0.1948
# Epoch 61/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4587 - accuracy: 0.8567 - val_loss: 5.5693 - val_accuracy: 0.1948
# Epoch 62/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.4099 - accuracy: 0.8893 - val_loss: 5.8837 - val_accuracy: 0.1818
# Epoch 63/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4069 - accuracy: 0.9023 - val_loss: 5.8840 - val_accuracy: 0.1688
# Epoch 64/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.4708 - accuracy: 0.8697 - val_loss: 5.9257 - val_accuracy: 0.1688
# Epoch 65/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4202 - accuracy: 0.8860 - val_loss: 6.2734 - val_accuracy: 0.1948
# Epoch 66/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.4735 - accuracy: 0.8404 - val_loss: 6.1987 - val_accuracy: 0.1688
# Epoch 67/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4008 - accuracy: 0.8860 - val_loss: 6.0008 - val_accuracy: 0.1818
# Epoch 68/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3539 - accuracy: 0.8958 - val_loss: 6.3690 - val_accuracy: 0.1948
# Epoch 69/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.3017 - accuracy: 0.9349 - val_loss: 6.3467 - val_accuracy: 0.2078
# Epoch 70/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2923 - accuracy: 0.9283 - val_loss: 6.6850 - val_accuracy: 0.1688
# Epoch 71/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3084 - accuracy: 0.9121 - val_loss: 7.1272 - val_accuracy: 0.1688
# Epoch 72/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3335 - accuracy: 0.9121 - val_loss: 6.7240 - val_accuracy: 0.1818
# Epoch 73/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2784 - accuracy: 0.9251 - val_loss: 7.2498 - val_accuracy: 0.1558
# Epoch 74/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.3113 - accuracy: 0.9153 - val_loss: 6.8813 - val_accuracy: 0.1688
# Epoch 75/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2571 - accuracy: 0.9349 - val_loss: 6.7718 - val_accuracy: 0.1948
# Epoch 76/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2925 - accuracy: 0.9381 - val_loss: 7.3142 - val_accuracy: 0.1169
# Epoch 77/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2922 - accuracy: 0.9186 - val_loss: 7.1297 - val_accuracy: 0.1818
# Epoch 78/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2565 - accuracy: 0.9251 - val_loss: 7.1640 - val_accuracy: 0.1558
# Epoch 79/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2157 - accuracy: 0.9414 - val_loss: 7.2046 - val_accuracy: 0.1558
# Epoch 80/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2245 - accuracy: 0.9381 - val_loss: 7.1751 - val_accuracy: 0.1688
# Epoch 81/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1774 - accuracy: 0.9707 - val_loss: 7.6527 - val_accuracy: 0.1169
# Epoch 82/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1918 - accuracy: 0.9511 - val_loss: 7.7795 - val_accuracy: 0.1558
# Epoch 83/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1971 - accuracy: 0.9446 - val_loss: 7.4178 - val_accuracy: 0.1558
# Epoch 84/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1904 - accuracy: 0.9479 - val_loss: 7.8803 - val_accuracy: 0.1429
# Epoch 85/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1728 - accuracy: 0.9577 - val_loss: 7.7926 - val_accuracy: 0.1429
# Epoch 86/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1530 - accuracy: 0.9577 - val_loss: 7.8896 - val_accuracy: 0.1688
# Epoch 87/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1846 - accuracy: 0.9577 - val_loss: 8.4776 - val_accuracy: 0.1169
# Epoch 88/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2035 - accuracy: 0.9446 - val_loss: 7.4182 - val_accuracy: 0.1688
# Epoch 89/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1539 - accuracy: 0.9674 - val_loss: 7.9677 - val_accuracy: 0.1558
# Epoch 90/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1595 - accuracy: 0.9674 - val_loss: 8.4799 - val_accuracy: 0.1558
# Epoch 91/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1455 - accuracy: 0.9674 - val_loss: 8.5336 - val_accuracy: 0.1429
# Epoch 92/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1326 - accuracy: 0.9707 - val_loss: 8.3155 - val_accuracy: 0.1948
# Epoch 93/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1083 - accuracy: 0.9772 - val_loss: 8.7261 - val_accuracy: 0.1558
# Epoch 94/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1200 - accuracy: 0.9805 - val_loss: 9.2032 - val_accuracy: 0.1429
# Epoch 95/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1600 - accuracy: 0.9577 - val_loss: 8.4257 - val_accuracy: 0.1818
# Epoch 96/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1546 - accuracy: 0.9479 - val_loss: 8.2433 - val_accuracy: 0.1558
# Epoch 97/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1471 - accuracy: 0.9577 - val_loss: 8.6163 - val_accuracy: 0.1558
# Epoch 98/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1667 - accuracy: 0.9479 - val_loss: 8.6598 - val_accuracy: 0.1818
# Epoch 99/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1359 - accuracy: 0.9544 - val_loss: 9.1587 - val_accuracy: 0.1688
# Epoch 100/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1692 - accuracy: 0.9511 - val_loss: 8.4933 - val_accuracy: 0.1818

# %% [markdown]
# **3. Summary:
# It appears that the new model is overfit. From model1 to model3, they all perform pretty well on the texts that have been trained but very poorly on the text that have not been trained (validation set).**
#
# **I have applied several methods, including: increase cells from 75 to 100 in LSTM layer, increase epochs in training from 50 to 100, add dropout layer with dropout rate at 0.2, add two fully-connected layers with 50 nodes in each.**
#
# **My intutition is that increase LSTM cells and training epochs will improve performance, however, the model easily becomes overfit. I try to regulate the overfit issue by adding Dropout layer and two additional Dense layers, it has lower the accuracy for a little bit. When I tested with the model3 methods piped with validation set, the method does work and the model becomes less overfit (validation accuracy has incrased from 8% in model1 to 18% in model3). However, it is still overfit. I suspect the fundamental reason of overfit is due to the very small text corpus. I need a larger text corpus to train the model.**
